# %%
from tweets import *
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Correlation

# %%
df = tweets_analysis(
    'tweets.json',
    tags=[],
    bin_frequency='600s',
    stat_sign=0.6,
    print_corr=True,
)
df.head()
# Out:
# Statistical significance threshold: 0.6
#
# Correlations found!
#   Hashtag 1   Hashtag 2  Pearson R
# 0  #bigdata  #analytics   0.630000
# 1  #startup         #ai   0.622620
# 2  #startup  #analytics   0.640142
# 3  #startup    #bigdata   0.655205
# tag                  #acquisition   #ai  #analytics  #bigdata  #conference  \
# created_at
# 2019-02-11 11:00:00           6.0  72.0        10.0      28.0          7.0
# 2019-02-11 10:50:00           1.0  45.0        12.0      16.0          2.0
# 2019-02-11 10:40:00           3.0  44.0         6.0      19.0          9.0
# 2019-02-11 10:30:00           1.0  66.0        11.0      41.0          2.0
# 2019-02-11 10:20:00           2.0  63.0         8.0      21.0          4.0
#
# tag                  #meetup   #ml  #startup
# created_at
# 2019-02-11 11:00:00      4.0  12.0      42.0
# 2019-02-11 10:50:00      NaN   4.0      22.0
# 2019-02-11 10:40:00      4.0   4.0      20.0
# 2019-02-11 10:30:00      NaN   7.0      26.0
# ...

# %% [markdown]
# # Prediction

# %%
df = predict_tweet_counts(
    path='tweets.json',
    tag='#conference',
    time='600s',
    window_size=10,
)
df.head()
# Out:
# WARNING:tensorflow:From /Users/luizzanini/venvs/semrush/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /Users/luizzanini/venvs/semrush/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /Users/luizzanini/venvs/semrush/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/50
# ...
